# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
HousePrice = pd.read_csv('Average House Price.csv')

# %%
YoungPeopleParents = pd.read_csv('Percentage of young people 20 to 34 living with parents.csv')

# %%
HousePrice.head()
# Out:
#       Average price
# Year
# 1996          59885
# 1997          64604
# 1998          72469
# 1999          82504
# 2000          93624

# %%
YoungPeopleParents.head()
# Out:
#       Percentage living with parents
# Year
# 1996                              21
# 1997                              20
# 1998                              19
# 1999                              20
# 2000                              20

# %%
HousePrice = HousePrice.set_index('Year')

# %%
YoungPeopleParents = YoungPeopleParents.set_index('Year')

# %%
HousePrice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1996 to 2020
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Average price  25 non-null     int64
# dtypes: int64(1)
# memory usage: 400.0 bytes

# %%
YoungPeopleParents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1996 to 2020
# Data columns (total 1 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Percentage living with parents  25 non-null     int64
# dtypes: int64(1)
# memory usage: 400.0 bytes

# %%
HousePrice.plot(title='Average House Price', figsize=(10,6))

# %%
YoungPeopleParents.plot(title='Percentage of young people living with parents', figsize=(10,6))

# %%
frames = [HousePrice, YoungPeopleParents]

# %%
combinedDF = pd.concat(frames, axis=1)

# %%
combinedDF.head()
# Out:
#       Average price  Percentage living with parents
# Year
# 1996          59885                              21
# 1997          64604                              20
# 1998          72469                              19
# 1999          82504                              20
# 2000          93624                              20

# %%
combinedDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1996 to 2020
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Average price                   25 non-null     int64
#  1   Percentage living with parents  25 non-null     int64
# dtypes: int64(2)
# memory usage: 600.0 bytes

# %%
combinedDF.corr()
# Out:
#                                 Average price  Percentage living with parents
# Average price                        1.000000                        0.886905
# Percentage living with parents       0.886905                        1.000000
